# %% [markdown]
# Bài 1: Nhập vào 2 cạnh của một hình chữ nhật. In ra màn hình diệntíchvàchu vi của nó

# %%
a, b=map(float,input().split())
print("chu vi hình chữ nhật là",a*2+b*2)
print("diện tích hình chữ nhật là",a*b)
# Out:
# chu vi hình chữ nhật là 14.0
# diện tích hình chữ nhật là 10.0

# %% [markdown]
# Bài 2: Nhập vào bán kính của hình tròn. In ra màn hình diện tích và chu vi của nó.

# %%
r=float(input())
import math
dien_tich=math.pi*(r**2)
print("dien_tich hình tròn là",dien_tich)
chu_vi=2*math.pi*r
print("chu vi hình tròn là",chu_vi)
# Out:
# dien_tich hình tròn là 78.53981633974483
# chu vi hình tròn là 31.41592653589793

# %% [markdown]
# Bài 3 : Tính tam giác: Nhâp vào ba số a,b,c bất kì. Kiểmtra xem nó có thể làđộ dài ba cạnh hay không, nếu không thì in ra màn hình 'Khong la ba canh cua mot tam giac'. Ngược lại, kiểm tra xem nó là tam giác gì: Đều, Cân, Vuông, hay Tam giác thường. Tính diện tích, chu vi của tam giác và in ra mànhình.

# %%
a, b, c=map(float,input().split())
if a+b>c and a+c>b and b+c>a:
        if a==b==c:
            print("tam giác là tam giác đều")
        elif a==b !=c or a==c !=b or b==c !=a:
            print("tam giác là tam giác cân")
        elif a**2+b**2==c**2 or a**2+c**2==b**2 or b**2+c**2==a**2:
            print("tam giác là tam giác vuông")
        else:
             print("tam giác là tam giác thường")
        print("chu vi tam giác là",a+b+c)
        p=(a+b+c)/2
        dien_tich=(p*(p-a)*(p-b)*(p-c))**1/2
        print("diện tích tam giác là",dien_tich)
else:
     "không phải là tam giác"
# Out:
# tam giác là tam giác vuông
# chu vi tam giác là 12.0
# diện tích tam giác là 18.0

# %% [markdown]
# Bài 4: Viết chương trình giải phương trình bậc 1 (ax + b = 0)

# %%
a, b=map(float,input().split())
if a !=0 and b !=0:
    print(-b/a)
elif a==0 and b !=0:
    print("vô nghiệm")
elif a==0 and b==0:
    print("vô số nghiệm")
# Out:
# vô nghiệm

# %% [markdown]
# Bài 5: Viết chương trình giải phương trình bậc 2 (ax2 + bx + c = 0)

# %%
a, b, c=map(float,input().split())
if a==0 and b !=0:
    print("x=",-c/b)
elif a==0 and b==0 and c !=0:
    print("Phương trình vô nghiệm")
elif a==0 and b==0 and c==0:
    print("Phương trình có vô số nghiệm")
elif a !=0:
    delta=b**2-4*a*c
    if delta>=0:
        x1=(b+(delta)**1/2)/2*a
        print("x1=",x1)
        x2=(b-(delta)**1/2)/2*a
        print("x2=",x2)
    elif delta<0:
        print("phương trình vô nghiệm")
# Out:
# Phương trình có vô số nghiệm

# %% [markdown]
# Bài 6: Tìm giá trị lớn nhất trong 4 số a, b, c, d (a, b, c, được nhập từ bànphím).

# %%
a, b, c, d=map(float,input().split())
print(max(a,b,c,d))
# Out:
# 4.0

# %% [markdown]
# Bài 7: Tìm giá trị nhỏ nhất trong 4 số a, b, c, d (a, b, c, được nhập từ bànphím).

# %%
a, b, c, d=map(float,input().split())
print(min(a,b,c,d))
# Out:
# 1.0

# %% [markdown]
# Bài 8: Giải hệ phương trình tuyến tính:
# ax + by =m
# cx + dy =n

# %%
a, b, m, c, d, n=map(float,input().split())
if a==0 and b==0 and m==0 or c/a==d/b==n/m:
    print("Vô số nghiệm")
elif a==0 and b==0  and m !=0:
    print("Vô nghiệm")
elif c==0 and d==0 and n !=0:
    print("Vô nghiệm")
elif a==c and b==d and m!=n:
    print("Vô nghiệm")
else:
    y=(((c*m)/a)-n)/(((c*b)/a)-d)
    x=(m-b*y)/a
    print("x=",x)
    print("y=",y)
# Out:
# Vô nghiệm

# %% [markdown]
# Bài 9: Nhập vào thời gian 1 công việc nào đó là x giây. Hãy chuyển đổi và viết ra màn hình số thời gian trên dưới dạng bằng bao nhiêu giờ, bao nhiêu phút, bao nhiêu giây.

# %%
x=int(input())
gio=x//3600
phut=(x-gio*3600)//60
giay=(x-gio*3600-phut*60)
print(gio,"h",phut,"p",giay,"s")
# Out:
# 626 h 24 p 25 s

# %% [markdown]
# Bài 10: Nhập vào tâm và bán kính của một đường tròn. Sau đó nhập vàomộtđiểm A(x, y) bất kì và kiểm tra xem nó có thuộc đường tròn hay không?

# %%
a, b, r, x, y=map(float,input().split())
if (x-a)**2+(y-b)**2==r**2:
    print("A thuộc đường tròn")
else:
    print("A không thuộc đường tròn")
# Out:
# A thuộc đường tròn

# %% [markdown]
# Bài 11: Tính x^
# y (Với x, y là số thực)

# %%
x, y=map(float,input().split())
print(x**y)
# Out:
# 25.0
